# %% [markdown]
# #### Importing packages

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import plotly as py
import plotly.express as px
import missingno as msno
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import accuracy_score,recall_score, precision_score
# to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %% [markdown]
# #### Functions

# %%
# Function to remove missing values above a given threshold
def missing_remove(dataframe, threshold):
    columns = dataframe.columns[(dataframe.isna().sum()/dataframe.shape[1])>threshold].tolist()
    print(f"# Features deleted with more than {threshold} % missing values", len(columns))
    return dataframe.drop(columns, axis=1,inplace=True)

# %%
# Function to remove features with unique values
def unique_remove(dataframe):
    unique_features = []
    for col in dataframe.columns:
        if(dataframe[col].unique().size == 2):
            if(len(unique_features) == 0):
                unique_features =  dataframe[col]
            else:
                 unique_features = pd.concat([unique_features, dataframe[col]], axis=1)
            dataframe.drop(col, axis=1, inplace=True)

# %%
# Function to remove outlier
def outlier_detection_zcore(dataframe):
    data_mean, data_std  = dataframe.mean(), dataframe.std()
    data_z_scores = ((dataframe - data_mean) / data_std).abs()
    m = data_z_scores > 3
    dataframe = dataframe.mask(m,inplace=True)
    return dataframe

# %%
def rfc(X_train_rfc,X_test_rfc,y_train,max_depth):
  from matplotlib.pyplot import figure
  figure(figsize=(8, 5), dpi=80)
  model = RandomForestClassifier(n_estimators=100, criterion='entropy', max_depth=max_depth)
  model.fit(X_train_rfc, y_train)
  y_pred = model.predict(X_test_rfc)
  sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d",cmap="YlOrRd",yticklabels = ['Act. Pass', 'Act. Fail'], xticklabels = ['Pred. Pass' , 'Pred. Fail'])
  print(classification_report(y_test, y_pred))
  ax = plt.gca()
  plot = plot_roc_curve(model, X_test_rfc, y_test, ax=ax, alpha=0.8)
  print("Test Accuracy Score", accuracy_score(y_test, y_pred))
  f1score = f1_score(y_test, y_pred, average='micro')
  mccscore=matthews_corrcoef(y_test, y_pred)
  return f1score, mccscore

# %%
def evaluate1(model, X_train,X_test,y_train,y_test):
  from matplotlib.pyplot import figure
  figure(figsize=(8, 5), dpi=80)

  scaler = StandardScaler()
  scaler.fit(X_train)
  train_std = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
  test_std = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  cm=confusion_matrix(y_test, y_pred)
  #print(classification_report(y_test, y_pred))
  ax = plt.gca()
  plot = plot_roc_curve(model, X_test, y_test, ax=ax, alpha=0.8)
  print("Train Accuracy Score:", accuracy_score(y_train, model.predict(X_train)))
  print("Test Accuracy Score:", accuracy_score(y_test, y_pred))
  f1score = f1_score(y_test, y_pred, average='micro')
  mccscore=matthews_corrcoef(y_test, y_pred)
  recall = recall_score(y_test,y_pred)
  precision = precision_score(y_test,y_pred)
  specificity = cm[1,1]/(cm[1,1]+cm[0,1])
  sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
  FNR = cm[1,0]/(cm[1,0]+cm[0,0])
  FPR = cm[0,1]/(cm[0,1]+cm[1,1])
  specificity1 = 1 - FPR
  sensitivity1 = 1- FNR
  print("F1 Score:", f1score) 
  print("MC Score:" , mccscore)
  print("Sensitivity:" , sensitivity)
  print("Specificity:" , specificity)
  print("Recall:" , recall)
  print("Precision:" , precision)
  print("FNR:" , FNR)
  print("FPR:" , FPR)
  #print("Sensitivity1:" , sensitivity1)
  #print("Specificity1:" , specificity1)
  sns.heatmap(cm, annot=True, fmt="d",cmap="YlOrRd",yticklabels = ['Act. Pass', 'Act. Fail'], xticklabels = ['Pred. Pass' , 'Pred. Fail'])

# %%
def evaluate2(model, X_train,X_test,y_train,y_test):
  from matplotlib.pyplot import figure
  figure(figsize=(8, 5), dpi=80)

  scaler = StandardScaler()
  scaler.fit(X_train)
  X_train_std = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
  X_test_std = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

  model.fit(X_train_std, y_train)
  y_pred = model.predict(X_test_std)
  cm=confusion_matrix(y_test, y_pred)
  sns.heatmap(cm, annot=True, fmt="d",cmap="YlOrRd",yticklabels = ['Act. Pass', 'Act. Fail'], xticklabels = ['Pred. Pass' , 'Pred. Fail'])
  #print(classification_report(y_test, y_pred))
  ax = plt.gca()
  plot = plot_roc_curve(model, X_test_std, y_test, ax=ax, alpha=0.8)
  print("Model Name:", model)
  print("Train Accuracy Score:", accuracy_score(y_train, model.predict(X_train_std)))
  print("Test Accuracy Score:", accuracy_score(y_test, y_pred))
  f1score = f1_score(y_test, y_pred, average='micro')
  mccscore=matthews_corrcoef(y_test, y_pred)
  recall = recall_score(y_test,y_pred)
  precision = precision_score(y_test,y_pred)
  specificity = cm[1,1]/(cm[1,1]+cm[0,1])
  sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
  FNR = cm[1,0]/(cm[1,0]+cm[0,0])
  FPR = cm[0,1]/(cm[0,1]+cm[1,1])
  specificity1 = 1 - FPR
  sensitivity1 = 1- FNR
  print("F1 Score:", f1score) 
  print("MC Score:" , mccscore)
  print("Sensitivity:" , sensitivity)
  print("Specificity:" , specificity)
  print("Recall:" , recall)
  print("Precision:" , precision)
  print("FNR:" , FNR)
  print(f"FPR: {FPR}\n" )
  #print("Sensitivity1:" , sensitivity1)
  #print("Specificity1:" , specificity1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, matthews_corrcoef
from yellowbrick.classifier import ConfusionMatrix, ClassPredictionError
def evaluate(train_df, test_df, train_target, test_target):
    
    scaler = StandardScaler()
    scaler.fit(train_df)
    train_std = pd.DataFrame(scaler.transform(train_df), columns=train_df.columns)
    test_std = pd.DataFrame(scaler.transform(test_df), columns=test_df.columns)
    
    logreg = LogisticRegression(random_state = 42, class_weight='balanced', C=200, dual=False, solver='liblinear')
    logreg.fit(train_std, train_target.values.ravel())
    
    y_pred = logreg.predict(test_std)
    y_true = test_target.values.ravel()
    f1score = f1_score(y_true, y_pred, average='micro')
    mccscore=matthews_corrcoef(y_true, y_pred)
    
   
    cm = ConfusionMatrix(logreg, classes=['Fail', 'Pass'], cmap="YlGn", size=(400,400))
    cm.score(test_std, y_true)
    cm.show()
    from matplotlib.pyplot import figure
    figure(figsize=(5, 5), dpi=80)
    ax = plt.gca()
    plot = plot_roc_curve(logreg, test_df, test_target, ax=ax, alpha=0.8)
    
    return f1score, mccscore

# %% [markdown]
# #### Importing and basic cleaning

# %%
# Importing data from internet in runtime
data_url="https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom.data"

# %%
# Assigning data to a pandas dataframe
secom_data = pd.read_csv(data_url,sep=' ',header=None)

# %%
# Renaming the columns 
secom_data.columns = ["Feature_"+str(column+1) for column in range(len(secom_data.columns))]
secom_data.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    3030.93    2564.00  2187.7333  1411.1265     1.3602      100.0
# 1    3095.78    2465.14  2230.4222  1463.6606     0.8294      100.0
# 2    2932.61    2559.94  2186.4111  1698.0172     1.5102      100.0
# 3    2988.72    2479.90  2199.0333   909.7926     1.3204      100.0
# 4    3032.24    2502.87  2233.3667  1326.5200     1.5334      100.0
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_581  Feature_582  \
# 0    97.6133     0.1242     1.5005      0.0162  ...          NaN          NaN
# 1   102.3433     0.1247     1.4966     -0.0005  ...       0.0060     208.2045
# 2    95.4878     0.1241     1.4436      0.0041  ...       0.0148      82.8602
# 3   104.2367     0.1217     1.4882     -0.0124  ...       0.0044      73.8432
# 4   100.3967     0.1235     1.5031     -0.0031  ...          NaN          NaN
#
#    Feature_583  Feature_584  Feature_585  Feature_586  Feature_587  \
# 0       0.5005       0.0118       0.0035       2.3630          NaN
# 1       0.5019       0.0223       0.0055       4.4447       0.0096
# 2       0.4958       0.0157       0.0039       3.1745       0.0584
# 3       0.4990       0.0103       0.0025       2.0544       0.0202
# 4       0.4800       0.4766       0.1045      99.3032       0.0202
#
#    Feature_588  Feature_589  Feature_590
# 0          NaN          NaN          NaN
# 1       0.0201       0.0060     208.2045
# 2       0.0484       0.0148      82.8602
# 3       0.0149       0.0044      73.8432
# 4       0.0149       0.0044      73.8432
#
# [5 rows x 590 columns]

# %%
# Importing target data from internet in runtime
label_url="https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom_labels.data"

# %%
# Assigning target data to a pandas dataframe
secom_labels = pd.read_csv(label_url, sep = " ",header=None)

# %%
# Renaming the columns 
secom_labels.columns = ["Classification","Timestamp"]

# %%
# Changing datatype for consitency
secom_labels['Timestamp'] = pd.to_datetime(secom_labels['Timestamp'],errors='raise')

# %%
# Merging the data
data= pd.concat([secom_labels,secom_data],axis=1)

# %%
# Dropping the timestamp column as it provides no insights
data.drop(columns="Timestamp", errors='raise',inplace=True)

# %%
target = data[['Classification']]
data.drop(['Classification'], axis=1,inplace=True)

# %% [markdown]
# #### Spliting the data into training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data,target, test_size=0.20, random_state=42, stratify=target)
# We use the startify parameter as the data is imbalanced on the basis of pass and fail and this will ensure the same 
#is retained when we split - Random state will help us create a reproducible data - Test size is the split ration

# %%
X_test_original = X_test

# %% [markdown]
# #### Re-labeling the Target values

# %%
# # Relabeling target variables 1 is pass and 0 is fail
# y_train = y_train.replace(to_replace=[-1, 1], value=[1, 0])
# y_test = y_test.replace(to_replace=[-1, 1], value=[1, 0])

# %%
# # Scaling the data
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
# X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# # Decision : Removing columns with more that 50% missing values

# %%
X_train.shape
# Out:
# (1253, 590)

# %%
X_train_missing = X_train
missing_remove(X_train_missing, 0.5)
X_train_missing.shape
# Out:
# # Features deleted with more than 0.5 % missing values 32
# (1253, 558)

# %% [markdown]
# ## Removing Unique cols

# %%
# X_train_unique = X_train_missing
# unique_remove(X_train_unique)
# X_train_unique.shape

# %%
# From test set deleting columns that are removed in training set
X_test_missing = X_test[np.array(X_train_missing.columns)]
X_test_missing.shape
# Out:
# (314, 558)

# %% [markdown]
# # Decision : Replacing outliers with 3s boundary

# %% [markdown]
# ##### Other option of removing outliers and replacing them has been explored in file "Base file - removing outliers and replacing with knn.ipynb"

# %%
def replace_outlier(val, mean, std):
    if val > mean + 3*std:
        return mean + 3*std 
    elif val < mean - 3*std:
        return mean - 3*std
    return val

# %%
# replace with 3s in X_train
for col in X_train_missing.columns:
    mean = X_train_missing[col].mean()
    std_dev = X_train_missing[col].std(axis=0)
    X_train_missing[col] = X_train_missing[col].map(lambda x: replace_outlier(x, mean, std_dev))

# %%
# replace with 3s in X_test
for col in X_test_missing.columns:
    mean = X_test_missing[col].mean()
    std_dev = X_test_missing[col].std(axis=0)
    X_test_missing[col] = X_test_missing[col].map(lambda x: replace_outlier(x, mean, std_dev))

# %% [markdown]
# # KNN Imputation

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer()
knn.fit(X_train_missing)
X_train_knn=pd.DataFrame(knn.transform(X_train_missing), columns=X_train_missing.columns)
X_train_knn.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer()
knn.fit(X_test_missing)
X_test_knn=pd.DataFrame(knn.transform(X_test_missing), columns=X_test_missing.columns)
X_test_knn.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Boruta - 15 features

# %%
pip install boruta
# Out:
# Requirement already satisfied: boruta in c:\users\public\anaconda3\lib\site-packages (0.3)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\public\anaconda3\lib\site-packages (from boruta) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.17.1 in c:\users\public\anaconda3\lib\site-packages (from boruta) (1.1.1)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\public\anaconda3\lib\site-packages (from boruta) (1.7.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\public\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\public\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Boruta function

def BorutaFeatureSelection (X, y) :
    feature_names = np.array(X.columns)

    model = model = RandomForestClassifier(n_estimators=200, n_jobs=-1, max_depth=6,class_weight='balanced_subsample')
    model.fit(X, y)
    
    feature_selector = BorutaPy(model, random_state=2, verbose=2,max_iter=455,n_estimators=200)

    feature_selector.fit(X.to_numpy(),y)

    feature_selector.support_

    feature_selector.ranking_

    feature_ranks = list(zip(feature_names, 
                             feature_selector.ranking_, 
                             feature_selector.support_))

    for feat in feature_ranks:
        print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
        
    final_features = list()
    indexes = np.where(feature_selector.ranking_ <= 1)
    for x in np.nditer(indexes):
        final_features.append(feature_names[x])
    print(final_features)
    
    return pd.DataFrame(X.filter(final_features)) , final_features

# %%
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy
X_train_boruta , final_features = BorutaFeatureSelection(X_train_knn,y_train.values.ravel())
# Out:
# Iteration: 	1 / 455
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	2 / 455
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	3 / 455
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	4 / 455
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	5 / 455
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	6 / 455
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	7 / 455
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	8 / 455
# Confirmed: 	0
# Tentative: 	27
# Rejected: 	531
# Iteration: 	9 / 455
# Confirmed: 	2
# Tentative: 	25
# Rejected: 	531
# Iteration: 	10 / 455
# Confirmed: 	2
# Tentative: 	25
# Rejected: 	531
# Iteration: 	11 / 455
# Confirmed: 	2
# Tentative: 	25
# Rejected: 	531
# Iteration: 	12 / 455
# Confirmed: 	6
# Tentative: 	18
# Rejected: 	534
# Iteration: 	13 / 455
# Confirmed: 	6
# Tentative: 	18
# Rejected: 	534
# Iteration: 	14 / 455
# Confirmed: 	6
# Tentative: 	18
# Rejected: 	534
# Iteration: 	15 / 455
# Confirmed: 	6
# Tentative: 	18
# Rejected: 	534
# Iteration: 	16 / 455
# Confirmed: 	6
# Tentative: 	18
# Rejected: 	534
# Iteration: 	17 / 455
# Confirmed: 	6
# Tentative: 	18
# Rejected: 	534
# Iteration: 	18 / 455
# Confirmed: 	6
# Tentative: 	18
# Rejected: 	534
# Iteration: 	19 / 455
# Confirmed: 	7
# Tentative: 	17
# Rejected: 	534
# Iteration: 	20 / 455
# Confirmed: 	7
# Tentative: 	17
# Rejected: 	534
# Iteration: 	21 / 455
# Confirmed: 	7
# Tentative: 	17
# Rejected: 	534
# Iteration: 	22 / 455
# Confirmed: 	7
# Tentative: 	17
# Rejected: 	534
# Iteration: 	23 / 455
# Confirmed: 	7
# Tentative: 	17
# Rejected: 	534
# Iteration: 	24 / 455
# Confirmed: 	7
# Tentative: 	17
# Rejected: 	534
# Iteration: 	25 / 455
# Confirmed: 	7
# Tentative: 	17
# Rejected: 	534
# Iteration: 	26 / 455
# Confirmed: 	9
# Tentative: 	15
# Rejected: 	534
# Iteration: 	27 / 455
# Confirmed: 	9
# Tentative: 	15
# Rejected: 	534
# Iteration: 	28 / 455
# Confirmed: 	9
# Tentative: 	15
# Rejected: 	534
# Iteration: 	29 / 455
# Confirmed: 	10
# Tentative: 	14
# Rejected: 	534
# Iteration: 	30 / 455
# Confirmed: 	10
# Tentative: 	14
# Rejected: 	534
# Iteration: 	31 / 455
# Confirmed: 	10
# Tentative: 	14
# Rejected: 	534
# Iteration: 	32 / 455
# Confirmed: 	11
# Tentative: 	13
# Rejected: 	534
# Iteration: 	33 / 455
# Confirmed: 	11
# Tentative: 	13
# Rejected: 	534
# Iteration: 	34 / 455
# Confirmed: 	11
# Tentative: 	12
# Rejected: 	535
# Iteration: 	35 / 455
# Confirmed: 	11
# Tentative: 	12
# Rejected: 	535
# Iteration: 	36 / 455
# Confirmed: 	11
# Tentative: 	12
# Rejected: 	535
# Iteration: 	37 / 455
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	535
# Iteration: 	38 / 455
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	535
# Iteration: 	39 / 455
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	535
# Iteration: 	40 / 455
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	535
# Iteration: 	41 / 455
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	535
# Iteration: 	42 / 455
# Confirmed: 	13
# Tentative: 	10
# Rejected: 	535
# Iteration: 	43 / 455
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	535
# Iteration: 	44 / 455
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	535
# Iteration: 	45 / 455
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	535
# Iteration: 	46 / 455
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	535
# Iteration: 	47 / 455
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	535
# Iteration: 	48 / 455
# Confirmed: 	14
# Tentative: 	9
# Rejected: 	535
# Iteration: 	49 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	50 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	51 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	52 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	53 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	54 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	55 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	56 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	57 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	58 / 455
# Confirmed: 	15
# Tentative: 	8
# Rejected: 	535
# Iteration: 	59 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	60 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	61 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	62 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	63 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	64 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	65 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	66 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	67 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	68 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	69 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	70 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	71 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	72 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	73 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	74 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	75 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	76 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	77 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	78 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	79 / 455
# Confirmed: 	16
# Tentative: 	7
# Rejected: 	535
# Iteration: 	80 / 455
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	535
# Iteration: 	81 / 455
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	535
# Iteration: 	82 / 455
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	535
# Iteration: 	83 / 455
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	535
# Iteration: 	84 / 455
# Confirmed: 	17
# Tentative: 	6
# Rejected: 	535
# Iteration: 	85 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	86 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	87 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	88 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	89 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	90 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	91 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	92 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	93 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	94 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	95 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	96 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	97 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	98 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	99 / 455
# Confirmed: 	18
# Tentative: 	5
# Rejected: 	535
# Iteration: 	100 / 455
# Confirmed: 	18
# Tentative: 	4
# Rejected: 	536
# Iteration: 
/ 455
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	536
# Iteration: 	453 / 455
# Confirmed: 	19
# Tentative: 	3
# Rejected: 	536
# Iteration: 	454 / 455
# Confirmed: 	20
# Tentative: 	2
# Rejected: 	536
#
#
# BorutaPy finished running.
#
# Iteration: 	455 / 455
# Confirmed: 	20
# Tentative: 	1
# Rejected: 	536
# Feature: Feature_1                      Rank: 23,  Keep: False
# Feature: Feature_2                      Rank: 278,  Keep: False
# Feature: Feature_3                      Rank: 245,  Keep: False
# Feature: Feature_4                      Rank: 319,  Keep: False
# Feature: Feature_5                      Rank: 294,  Keep: False
# Feature: Feature_6                      Rank: 479,  Keep: False
# Feature: Feature_7                      Rank: 348,  Keep: False
# Feature: Feature_8                      Rank: 231,  Keep: False
# Feature: Feature_9                      Rank: 50,  Keep: False
# Feature: Feature_10                     Rank: 126,  Keep: False
# Feature: Feature_11                     Rank: 73,  Keep: False
# Feature: Feature_12                     Rank: 400,  Keep: False
# Feature: Feature_13                     Rank: 188,  Keep: False
# Feature: Feature_14                     Rank: 479,  Keep: False
# Feature: Feature_15                     Rank: 5,  Keep: False
# Feature: Feature_16                     Rank: 122,  Keep: False
# Feature: Feature_17                     Rank: 44,  Keep: False
# Feature: Feature_18                     Rank: 311,  Keep: False
# Feature: Feature_19                     Rank: 308,  Keep: False
# Feature: Feature_20                     Rank: 54,  Keep: False
# Feature: Feature_21                     Rank: 205,  Keep: False
# Feature: Feature_22                     Rank: 1,  Keep: True
# Feature: Feature_23                     Rank: 181,  Keep: False
# Feature: Feature_24                     Rank: 271,  Keep: False
# Feature: Feature_25                     Rank: 359,  Keep: False
# Feature: Feature_26                     Rank: 140,  Keep: False
# Feature: Feature_27                     Rank: 313,  Keep: False
# Feature: Feature_28                     Rank: 135,  Keep: False
# Feature: Feature_29                     Rank: 4,  Keep: False
# Feature: Feature_30                     Rank: 246,  Keep: False
# Feature: Feature_31                     Rank: 320,  Keep: False
# Feature: Feature_32                     Rank: 1,  Keep: True
# Feature: Feature_33                     Rank: 361,  Keep: False
# Feature: Feature_34                     Rank: 1,  Keep: True
# Feature: Feature_35                     Rank: 240,  Keep: False
# Feature: Feature_36                     Rank: 72,  Keep: False
# Feature: Feature_37                     Rank: 149,  Keep: False
# Feature: Feature_38                     Rank: 42,  Keep: False
# Feature: Feature_39                     Rank: 303,  Keep: False
# Feature: Feature_40                     Rank: 81,  Keep: False
# Feature: Feature_41                     Rank: 54,  Keep: False
# Feature: Feature_42                     Rank: 341,  Keep: False
# Feature: Feature_43                     Rank: 479,  Keep: False
# Feature: Feature_44                     Rank: 146,  Keep: False
# Feature: Feature_45                     Rank: 276,  Keep: False
# Feature: Feature_46                     Rank: 249,  Keep: False
# Feature: Feature_47                     Rank: 317,  Keep: False
# Feature: Feature_48                     Rank: 223,  Keep: False
# Feature: Feature_49                     Rank: 199,  Keep: False
# Feature: Feature_50                     Rank: 479,  Keep: False
# Feature: Feature_51                     Rank: 148,  Keep: False
# Feature: Feature_52                     Rank: 192,  Keep: False
# Feature: Feature_53                     Rank: 479,  Keep: False
# Feature: Feature_54                     Rank: 242,  Keep: False
# Feature: Feature_55                     Rank: 291,  Keep: False
# Feature: Feature_56                     Rank: 90,  Keep: False
# Feature: Feature_57                     Rank: 7,  Keep: False
# Feature: Feature_58                     Rank: 237,  Keep: False
# Feature: Feature_59                     Rank: 40,  Keep: False
# Feature: Feature_60                     Rank: 1,  Keep: True
# Feature: Feature_61                     Rank: 383,  Keep: False
# Feature: Feature_62                     Rank: 137,  Keep: False
# Feature: Feature_63                     Rank: 71,  Keep: False
# Feature: Feature_64                     Rank: 37,  Keep: False
# Feature: Feature_65                     Rank: 1,  Keep: True
# Feature: Feature_66                     Rank: 1,  Keep: True
# Feature: Feature_67                     Rank: 89,  Keep: False
# Feature: Feature_68                     Rank: 83,  Keep: False
# Feature: Feature_69                     Rank: 225,  Keep: False
# Feature: Feature_70                     Rank: 479,  Keep: False
# Feature: Feature_71                     Rank: 29,  Keep: False
# Feature: Feature_72                     Rank: 256,  Keep: False
# Feature: Feature_75                     Rank: 479,  Keep: False
# Feature: Feature_76                     Rank: 156,  Keep: False
# Feature: Feature_77                     Rank: 182,  Keep: False
# Feature: Feature_78                     Rank: 233,  Keep: False
# Feature: Feature_79                     Rank: 44,  Keep: False
# Feature: Feature_80                     Rank: 103,  Keep: False
# Feature: Feature_81                     Rank: 277,  Keep: False
# Feature: Feature_82                     Rank: 36,  Keep: False
# Feature: Feature_83                     Rank: 328,  Keep: False
# Feature: Feature_84                     Rank: 176,  Keep: False
# Feature: Feature_85                     Rank: 226,  Keep: False
# Feature: Feature_87                     Rank: 237,  Keep: False
# Feature: Feature_88                     Rank: 285,  Keep: False
# Feature: Feature_89                     Rank: 184,  Keep: False
# Feature: Feature_90                     Rank: 156,  Keep: False
# Feature: Feature_91                     Rank: 46,  Keep: False
# Feature: Feature_92                     Rank: 80,  Keep: False
# Feature: Feature_93                     Rank: 153,  Keep: False
# Feature: Feature_94                     Rank: 338,  Keep: False
# Feature: Feature_95                     Rank: 410,  Keep: False
# Feature: Feature_96                     Rank: 190,  Keep: False
# Feature: Feature_97                     Rank: 203,  Keep: False
# Feature: Feature_98                     Rank: 479,  Keep: False
# Feature: Feature_99                     Rank: 280,  Keep: False
# Feature: Feature_100                    Rank: 275,  Keep: False
# Feature: Feature_101                    Rank: 23,  Keep: False
# Feature: Feature_102                    Rank: 413,  Keep: False
# Feature: Feature_103                    Rank: 11,  Keep: False
# Feature: Feature_104                    Rank: 1,  Keep: True
# Feature: Feature_105                    Rank: 267,  Keep: False
# Feature: Feature_106                    Rank: 352,  Keep: False
# Feature: Feature_107                    Rank: 253,  Keep: False
# Feature: Feature_108                    Rank: 102,  Keep: False
# Feature: Feature_109                    Rank: 325,  Keep: False
# Feature: Feature_114                    Rank: 165,  Keep: False
# Feature: Feature_115                    Rank: 414,  Keep: False
# Feature: Feature_116                    Rank: 127,  Keep: False
# Feature: Feature_117                    Rank: 140,  Keep: False
# Feature: Feature_118                    Rank: 96,  Keep: False
# Feature: Feature_119                    Rank: 254,  Keep: False
# Feature: Feature_120                    Rank: 343,  Keep: False
# Feature: Feature_121                    Rank: 250,  Keep: False
# Feature: Feature_122                    Rank: 1,  Keep: True
# Feature: Feature_123                    Rank: 13,  Keep: False
# Feature: Feature_124                    Rank: 68,  Keep: False
# Feature: Feature_125                    Rank: 33,  Keep: False
# %%
# From test set deleting columns that are removed in training set
X_test_boruta = X_test_knn[np.array(X_train_boruta.columns)]
X_test_boruta.shape
# Out:
# (314, 20)

# %%
import seaborn as sns
# Heatmap for correlation
plt.rcParams['figure.figsize'] = (15,15)
sns.heatmap(X_train_boruta.corr(),cmap="YlOrRd",annot=True)
plt.title('Heatmap for the Data', fontsize = 50)
# Out:
# Text(0.5, 1.0, 'Heatmap for the Data')

# %% [markdown]
# ## Balancing using SMOTE

# %%
import numpy as np
from imblearn.over_sampling import SMOTE, ADASYN, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA

# %%
from imblearn.combine import SMOTETomek 
# Sampling technique

def Sampling(X_train, y_train, sampler):

    #SMOTE
    if sampler == 'SMOTE':
        sampler = SMOTE(random_state=100)    
    

    #ADASYN
    if sampler == 'ADASYN':
        sampler = ADASYN(random_state=100)
        
    #ROSE
    if sampler == 'ROSE':
        sampler = RandomOverSampler(random_state=100, shrinkage=1)
        

    X_resampled, y_resampled = sampler.fit_resample(X_train, y_train)
    counter = Counter(y_resampled)
    print(counter)
    return X_resampled, y_resampled

# %%
# Imbalance treatment
from collections import Counter
X_smote, y_smote = Sampling(X_train_boruta, y_train,'SMOTE')
# Out:
# Counter({'Classification': 1})

# %%
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import cross_val_score
from sklearn.metrics import plot_confusion_matrix, classification_report, confusion_matrix
from sklearn.naive_bayes import GaussianNB

evaluate2(LogisticRegression(random_state = 42, class_weight='balanced', C=200, dual=False, solver='liblinear'),X_smote,X_test_boruta,y_smote,y_test)
evaluate2(RandomForestClassifier(n_jobs=-1, class_weight='balanced_subsample', max_depth=6, random_state=100),X_smote,X_test_boruta,y_smote,y_test)
evaluate2(svm.SVC(),X_smote,X_test_boruta,y_smote,y_test)
evaluate2(KNeighborsClassifier(n_neighbors=5),X_smote,X_test_boruta,y_smote,y_test)
evaluate2(DecisionTreeClassifier(criterion='entropy', max_depth=6),X_smote,X_test_boruta,y_smote,y_test)
evaluate2(GaussianNB(),X_smote,X_test_boruta,y_smote,y_test)
# Out:
# Model Name: LogisticRegression(C=200, class_weight='balanced', random_state=42,
#                    solver='liblinear')
# Train Accuracy Score: 0.7735042735042735
# Test Accuracy Score: 0.7484076433121019
# F1 Score: 0.7484076433121017
# MC Score: 0.1891085885485535
# Sensitivity: 0.9612068965517241
# Specificity: 0.14634146341463414
# Recall: 0.5714285714285714
# Precision: 0.14634146341463414
# FNR: 0.03879310344827586
# FPR: 0.8536585365853658
#
# Model Name: RandomForestClassifier(class_weight='balanced_subsample', max_depth=6,
#                        n_jobs=-1, random_state=100)
# Train Accuracy Score: 0.9307692307692308
# Test Accuracy Score: 0.7961783439490446
# F1 Score: 0.7961783439490446
# MC Score: 0.10543544380492104
# Sensitivity: 0.9455252918287937
# Specificity: 0.12280701754385964
# Recall: 0.3333333333333333
# Precision: 0.12280701754385964
# FNR: 0.054474708171206226
# FPR: 0.8771929824561403
#
# Model Name: SVC()
# Train Accuracy Score: 0.95
# Test Accuracy Score: 0.8757961783439491
# F1 Score: 0.8757961783439491
# MC Score: 0.26378690938559307
# Sensitivity: 0.9568345323741008
# Specificity: 0.25
# Recall: 0.42857142857142855
# Precision: 0.25
# FNR: 0.04316546762589928
# FPR: 0.75
#
# Model Name: KNeighborsClassifier()
# Train Accuracy Score: 0.8987179487179487
# Test Accuracy Score: 0.7197452229299363
# F1 Score: 0.7197452229299363
# MC Score: 0.18931917042653365
# Sensitivity: 0.9638009049773756
# Specificity: 0.13978494623655913
# Recall: 0.6190476190476191
# Precision: 0.13978494623655913
# FNR: 0.03619909502262444
# FPR: 0.8602150537634409
#
# Model Name: DecisionTreeClassifier(criterion='entropy', max_depth=6)
# Train Accuracy Score: 0.8239316239316239
# Test Accuracy Score: 0.6624203821656051
# F1 Score: 0.6624203821656051
# MC Score: 0.1487076053451383
# Sensitivity: 0.9605911330049262
# Specificity: 0.11711711711711711
# Recall: 0.6190476190476191
# Precision: 0.11711711711711711
# FNR: 0.03940886699507389
# FPR: 0.8828828828828829
#
# Model Name: GaussianNB()
# Train Accuracy Score: 0.773931623931624
# Test Accuracy Score: 0.7261146496815286
# F1 Score: 0.7261146496815287
# MC Score: 0.1942867744721218
# Sensitivity: 0.9641255605381166
# Specificity: 0.14285714285714285
# Recall: 0.6190476190476191
# Precision: 0.14285714285714285
# FNR: 0.03587443946188341
# FPR: 0.8571428571428571

# %% [markdown]
# ## Adasyn

# %%
# Imbalance treatment
X_adasyn, y_adasyn = Sampling(X_train_boruta, y_train,'ADASYN')
# Out:
# Counter({'Classification': 1})

# %%
evaluate2(LogisticRegression(random_state = 42, class_weight='balanced', C=200, dual=False, solver='liblinear'),X_adasyn,X_test_boruta,y_adasyn,y_test)
evaluate2(RandomForestClassifier(n_jobs=-1, class_weight='balanced_subsample', max_depth=6, random_state=100),X_adasyn,X_test_boruta,y_adasyn,y_test)
evaluate2(svm.SVC(),X_adasyn,X_test_boruta,y_adasyn,y_test)
evaluate2(KNeighborsClassifier(n_neighbors=5),X_adasyn,X_test_boruta,y_adasyn,y_test)
evaluate2(DecisionTreeClassifier(criterion='entropy', max_depth=6),X_adasyn,X_test_boruta,y_adasyn,y_test)
evaluate2(GaussianNB(),X_adasyn,X_test_boruta,y_adasyn,y_test)
# Out:
# Model Name: LogisticRegression(C=200, class_weight='balanced', random_state=42,
#                    solver='liblinear')
# Train Accuracy Score: 0.7609254498714653
# Test Accuracy Score: 0.7452229299363057
# F1 Score: 0.7452229299363057
# MC Score: 0.18643890084413106
# Sensitivity: 0.961038961038961
# Specificity: 0.14457831325301204
# Recall: 0.5714285714285714
# Precision: 0.14457831325301204
# FNR: 0.03896103896103896
# FPR: 0.8554216867469879
#
# Model Name: RandomForestClassifier(class_weight='balanced_subsample', max_depth=6,
#                        n_jobs=-1, random_state=100)
# Train Accuracy Score: 0.9318766066838047
# Test Accuracy Score: 0.8439490445859873
# F1 Score: 0.8439490445859873
# MC Score: 0.15696518437873808
# Sensitivity: 0.9485294117647058
# Specificity: 0.16666666666666666
# Recall: 0.3333333333333333
# Precision: 0.16666666666666666
# FNR: 0.051470588235294115
# FPR: 0.8333333333333334
#
# Model Name: SVC()
# Train Accuracy Score: 0.9541559554413025
# Test Accuracy Score: 0.8694267515923567
# F1 Score: 0.8694267515923567
# MC Score: 0.25245161525506155
# Sensitivity: 0.9565217391304348
# Specificity: 0.23684210526315788
# Recall: 0.42857142857142855
# Precision: 0.23684210526315788
# FNR: 0.043478260869565216
# FPR: 0.7631578947368421
#
# Model Name: KNeighborsClassifier()
# Train Accuracy Score: 0.8941730934018852
# Test Accuracy Score: 0.7101910828025477
# F1 Score: 0.7101910828025477
# MC Score: 0.15903902842938678
# Sensitivity: 0.9590909090909091
# Specificity: 0.1276595744680851
# Recall: 0.5714285714285714
# Precision: 0.1276595744680851
# FNR: 0.04090909090909091
# FPR: 0.8723404255319149
#
# Model Name: DecisionTreeClassifier(criterion='entropy', max_depth=6)
# Train Accuracy Score: 0.844044558697515
# Test Accuracy Score: 0.6847133757961783
# F1 Score: 0.6847133757961783
# MC Score: 0.09480776089024047
# Sensitivity: 0.9490740740740741
# Specificity: 0.10204081632653061
# Recall: 0.47619047619047616
# Precision: 0.10204081632653061
# FNR: 0.05092592592592592
# FPR: 0.8979591836734694
#
# Model Name: GaussianNB()
# Train Accuracy Score: 0.7596401028277635
# Test Accuracy Score: 0.7165605095541401
# F1 Score: 0.7165605095541401
# MC Score: 0.18687529093040542
# Sensitivity: 0.9636363636363636
# Specificity: 0.13829787234042554
# Recall: 0.6190476190476191
# Precision: 0.13829787234042554
# FNR: 0.03636363636363636
# FPR: 0.8617021276595744

# %% [markdown]
# ## Rose

# %%
# Imbalance treatment
X_rose, y_rose = Sampling(X_train_boruta, y_train,'ROSE')
# Out:
# Counter({'Classification': 1})

# %%
evaluate2(LogisticRegression(random_state = 42, class_weight='balanced', C=200, dual=False, solver='liblinear'),X_rose,X_test_boruta,y_rose,y_test)
evaluate2(RandomForestClassifier(n_jobs=-1, class_weight='balanced_subsample', max_depth=6, random_state=100),X_rose,X_test_boruta,y_rose,y_test)
evaluate2(svm.SVC(),X_rose,X_test_boruta,y_rose,y_test)
evaluate2(KNeighborsClassifier(n_neighbors=5),X_rose,X_test_boruta,y_rose,y_test)
evaluate2(DecisionTreeClassifier(criterion='entropy', max_depth=6),X_rose,X_test_boruta,y_rose,y_test)
evaluate2(GaussianNB(),X_rose,X_test_boruta,y_rose,y_test)
# Out:
# Model Name: LogisticRegression(C=200, class_weight='balanced', random_state=42,
#                    solver='liblinear')
# Train Accuracy Score: 0.7252136752136752
# Test Accuracy Score: 0.7356687898089171
# F1 Score: 0.7356687898089171
# MC Score: 0.17862362403606025
# Sensitivity: 0.9605263157894737
# Specificity: 0.13953488372093023
# Recall: 0.5714285714285714
# Precision: 0.13953488372093023
# FNR: 0.039473684210526314
# FPR: 0.8604651162790697
#
# Model Name: RandomForestClassifier(class_weight='balanced_subsample', max_depth=6,
#                        n_jobs=-1, random_state=100)
# Train Accuracy Score: 0.9294871794871795
# Test Accuracy Score: 0.8662420382165605
# F1 Score: 0.8662420382165607
# MC Score: 0.3012646172041052
# 2337    -0.008440    15.879993     1.399542    -0.791118     0.704580
# 2338    -0.007519    15.715036     0.945289    -0.891212     0.741237
# 2339    -0.003739    15.748989     0.471641    -0.500205     0.831914
#
#       Feature_201  Feature_206  Feature_214  Feature_282  Feature_320  \
# 0       16.450000     7.070000     0.019100     0.010800     5.001800
# 1       19.070000     9.130000     0.113400     0.014000     8.943700
# 2       17.160000    12.110000     0.045900     0.024000     8.532400
# 3       15.940000    10.050000     0.104600     0.011100     8.892600
# 4       14.950000     5.790000     0.080500     0.011600     6.957000
# ...           ...          ...          ...          ...          ...
# 2335    29.813175    14.066065     0.043369     0.024961     9.854011
# 2336    14.337849     9.962762     0.076081     0.011672    10.277236
# 2337    25.664846     5.172194     0.021071     0.014264    11.446075
# 2338    21.755987    18.096512     0.060129     0.020167     7.199638
# 2339    21.419350    19.019907     0.034392     0.017495     6.483107
#
#       Feature_352  Feature_456  Feature_478  Feature_511
# 0        0.009200     2.545300     4.795500    52.791900
# 1        0.052000     4.267200     6.213400    59.205800
# 2        0.020200     4.024800     8.624600    58.492700
# 3        0.050900     4.620800     6.609600    50.746300
# 4        0.039000     3.126300     3.847500    73.294300
# ...           ...          ...          ...          ...
# 2335     0.031356     5.427121    12.496371   101.581427
# 2336     0.036712     5.045419     8.257354    81.760245
# 2337     0.017272     4.775660     2.369096    33.485059
# 2338     0.041562     3.032594    10.914548    77.255252
# 2339     0.033250     3.424767    11.000327    99.007898
#
# [2340 rows x 20 columns]

# %%
# Random forest
params = {'criterion' : ["gini","entropy","log_loss"],
          'max_depth':[4,5,6,7,8,9,10],
         'max_features':["sqrt","log2","auto",None]}
          

grid_searcher = GridSearchCV(RandomForestClassifier(n_estimators=100,random_state=42,n_jobs=-1), params,scoring='roc_auc', cv = 5, verbose=1)
grid_searcher.fit(X_rose, y_rose)
#plot_result_smoted_fe_tuned(grid_searcher, "dtc")
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [4, 5, 6, 7, 8, 9, 10],
#                          'max_features': ['sqrt', 'log2', 'auto', None]},
#              scoring='roc_auc', verbose=1)

# %%
grid_searcher.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt'}

# %%
grid_searcher.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, n_jobs=-1,
#                        random_state=42)

# %%
evaluate2(grid_searcher.best_estimator_,X_rose,X_test_boruta,y_rose,y_test)
# Out:
# Model Name: RandomForestClassifier(criterion='entropy', max_depth=10, n_jobs=-1,
#                        random_state=42)
# Train Accuracy Score: 0.9782051282051282
# Test Accuracy Score: 0.89171974522293
# F1 Score: 0.89171974522293
# MC Score: 0.37664500209645746
# Sensitivity: 0.9675090252707581
# Specificity: 0.32432432432432434
# Recall: 0.5714285714285714
# Precision: 0.32432432432432434
# FNR: 0.032490974729241874
# FPR: 0.6756756756756757

# %%
evaluate2(RandomForestClassifier(n_jobs=-1,max_depth=10,criterion="log_loss",max_features="log2",n_estimators=100,random_state=42),X_rose,X_test_boruta,y_rose,y_test)
# Out:
# Model Name: RandomForestClassifier(criterion='log_loss', max_depth=10, max_features='log2',
#                        n_jobs=-1, random_state=42)
# Train Accuracy Score: 0.9782051282051282
# Test Accuracy Score: 0.89171974522293
# F1 Score: 0.89171974522293
# MC Score: 0.37664500209645746
# Sensitivity: 0.9675090252707581
# Specificity: 0.32432432432432434
# Recall: 0.5714285714285714
# Precision: 0.32432432432432434
# FNR: 0.032490974729241874
# FPR: 0.6756756756756757

# %%
# from time import time

# #n_estimators = 500 gives better results 
# clf = RandomForestClassifier(n_estimators=500, random_state=7, n_jobs=-1)

# param_grid = {"max_depth": [3, 8, None],
#               "class_weight": [{-1:.90, 1:.10}, {-1:.93, 1:.07}, {-1:.99, 1:.01}],
#               "min_samples_split": [2, 3, 5],
#               "max_features": ["sqrt", "log2", "auto", None],
#               "criterion": ["gini", "entropy","log_loss"]}

# # run grid search
# grid_search = GridSearchCV(clf, param_grid=param_grid)
# start = time()
# grid_search.fit(X_rose, y_rose)

# print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
#      % (time() - start, len(grid_search.grid_scores_)))

# %%
# evaluate2(RandomForestClassifier(n_estimators=500, n_jobs=-1,max_features=None,min_samples_split=5,criterion="gini",max_depth=10,class_weight ={1: 0.01, -1: 0.99}),X_rose,X_test_boruta,y_rose,y_test)

# %%
# evaluate2(RandomForestClassifier(n_estimators = 500,n_jobs=-1, class_weight='balanced_subsample',criterion='gini',max_depth=8,max_features='sqrt' ),X_rose,X_test_boruta,y_rose,y_test)

# %%
# evaluate2(RandomForestClassifier(n_estimators = 500,n_jobs=-1, class_weight='balanced_subsample',criterion='entropy',max_depth=8,max_features='sqrt' ),X_rose,X_test_boruta,y_rose,y_test)

# %%
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split # for separating train and test data, scaling, model building, ...

# Evaluation using Startified K Fold cross validation
cv = StratifiedKFold(n_splits=5)
scores = cross_val_score(grid_searcher.best_estimator_, X_rose, y_rose, cv=cv, scoring = 'roc_auc')
print(scores.mean())
# fit
grid_searcher.best_estimator_.fit(X_rose, y_rose)    
# predict
y_pred_test = grid_searcher.best_estimator_.predict(X_test_boruta)
# View accuracy score
accuracyFinal = accuracy_score(y_test, y_pred_test)
print('Test Accuracy : ', accuracyFinal)
sns.heatmap(confusion_matrix(y_test, y_pred_test), annot=True, fmt="d",cmap="YlOrRd",yticklabels = ['Act. Pass', 'Act. Fail'], xticklabels = ['Pred. Pass' , 'Pred. Fail'])
# Out:
# 0.9682336182336183
# Test Accuracy :  0.89171974522293
# <AxesSubplot:>

# %%
# from sklearn.model_selection import KFold, StratifiedKFold, train_test_split # for separating train and test data, scaling, model building, ...

# # Evaluation using Startified K Fold cross validation
# cv = StratifiedKFold(n_splits=10)
# scores = cross_val_score(grid_searcher.best_estimator_, X_rose, y_rose, cv=cv, scoring = 'roc_auc')
# print(scores.mean())
# # fit
# grid_searcher.best_estimator_.fit(X_rose, y_rose)    
# # predict
# y_pred_test = grid_searcher.best_estimator_.predict(X_test_boruta)
# # View accuracy score
# accuracyFinal = accuracy_score(y_test, y_pred_test)
# print('Test Accuracy : ', accuracyFinal)
# sns.heatmap(confusion_matrix(y_test, y_pred_test), annot=True, fmt="d",cmap="YlOrRd",yticklabels = ['Act. Pass', 'Act. Fail'], xticklabels = ['Pred. Pass' , 'Pred. Fail'])
