# %% [markdown]
# #### Importing packages

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import plotly as py
import plotly.express as px
import missingno as msno
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import accuracy_score,recall_score, precision_score
# to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %% [markdown]
# #### Functions

# %%
# Function to remove missing values above a given threshold
def missing_remove(dataframe, threshold):
    columns = dataframe.columns[(dataframe.isna().sum()/dataframe.shape[1])>threshold].tolist()
    print(f"# Features deleted with more than {threshold} % missing values", len(columns))
    return dataframe.drop(columns, axis=1,inplace=True)

# %%
# Function to remove features with unique values
def unique_remove(dataframe):
    unique_features = []
    for col in dataframe.columns:
        if(dataframe[col].unique().size == 2):
            if(len(unique_features) == 0):
                unique_features =  dataframe[col]
            else:
                 unique_features = pd.concat([unique_features, dataframe[col]], axis=1)
            dataframe.drop(col, axis=1, inplace=True)

# %%
# Function to remove outlier
def outlier_detection_zcore(dataframe):
    data_mean, data_std  = dataframe.mean(), dataframe.std()
    data_z_scores = ((dataframe - data_mean) / data_std).abs()
    m = data_z_scores > 3
    dataframe = dataframe.mask(m,inplace=True)
    return dataframe

# %%
def evaluate2(model, X_train,X_test,y_train,y_test):
  from matplotlib.pyplot import figure
  figure(figsize=(8, 5), dpi=80)

  scaler = StandardScaler()
  scaler.fit(X_train)
  X_train_std = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
  X_test_std = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

  model.fit(X_train_std, y_train)
  y_pred = model.predict(X_test_std)
  cm=confusion_matrix(y_test, y_pred)
  sns.heatmap(cm, annot=True, fmt="d",cmap="YlOrRd",yticklabels = ['Act. Pass', 'Act. Fail'], xticklabels = ['Pred. Pass' , 'Pred. Fail'])
  #print(classification_report(y_test, y_pred))
  ax = plt.gca()
  plot = plot_roc_curve(model, X_test_std, y_test, ax=ax, alpha=0.8)
  print("Model Name:", model)
  print("Train Accuracy Score:", accuracy_score(y_train, model.predict(X_train_std)))
  print("Test Accuracy Score:", accuracy_score(y_test, y_pred))
  f1score = f1_score(y_test, y_pred, average='micro')
  mccscore=matthews_corrcoef(y_test, y_pred)
  recall = recall_score(y_test,y_pred)
  precision = precision_score(y_test,y_pred)
  specificity = cm[1,1]/(cm[1,1]+cm[0,1])
  sensitivity = cm[0,0]/(cm[0,0]+cm[1,0])
  FNR = cm[1,0]/(cm[1,0]+cm[0,0])
  FPR = cm[0,1]/(cm[0,1]+cm[1,1])
  specificity1 = 1 - FPR
  sensitivity1 = 1- FNR
  print("F1 Score:", f1score) 
  print("MC Score:" , mccscore)
  print("Sensitivity:" , sensitivity)
  print("Specificity:" , specificity)
  print("Recall:" , recall)
  print("Precision:" , precision)
  print("FNR:" , FNR)
  print(f"FPR: {FPR}\n" )
  #print("Sensitivity1:" , sensitivity1)
  #print("Specificity1:" , specificity1)

# %% [markdown]
# #### Importing and basic cleaning

# %%
# Importing data from internet in runtime
data_url="https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom.data"

# %%
# Assigning data to a pandas dataframe
secom_data = pd.read_csv(data_url,sep=' ',header=None)

# %%
# Renaming the columns 
secom_data.columns = ["Feature_"+str(column+1) for column in range(len(secom_data.columns))]
secom_data.head()
# Out:
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0    3030.93    2564.00  2187.7333  1411.1265     1.3602      100.0
# 1    3095.78    2465.14  2230.4222  1463.6606     0.8294      100.0
# 2    2932.61    2559.94  2186.4111  1698.0172     1.5102      100.0
# 3    2988.72    2479.90  2199.0333   909.7926     1.3204      100.0
# 4    3032.24    2502.87  2233.3667  1326.5200     1.5334      100.0
#
#    Feature_7  Feature_8  Feature_9  Feature_10  ...  Feature_581  Feature_582  \
# 0    97.6133     0.1242     1.5005      0.0162  ...          NaN          NaN
# 1   102.3433     0.1247     1.4966     -0.0005  ...       0.0060     208.2045
# 2    95.4878     0.1241     1.4436      0.0041  ...       0.0148      82.8602
# 3   104.2367     0.1217     1.4882     -0.0124  ...       0.0044      73.8432
# 4   100.3967     0.1235     1.5031     -0.0031  ...          NaN          NaN
#
#    Feature_583  Feature_584  Feature_585  Feature_586  Feature_587  \
# 0       0.5005       0.0118       0.0035       2.3630          NaN
# 1       0.5019       0.0223       0.0055       4.4447       0.0096
# 2       0.4958       0.0157       0.0039       3.1745       0.0584
# 3       0.4990       0.0103       0.0025       2.0544       0.0202
# 4       0.4800       0.4766       0.1045      99.3032       0.0202
#
#    Feature_588  Feature_589  Feature_590
# 0          NaN          NaN          NaN
# 1       0.0201       0.0060     208.2045
# 2       0.0484       0.0148      82.8602
# 3       0.0149       0.0044      73.8432
# 4       0.0149       0.0044      73.8432
#
# [5 rows x 590 columns]

# %%
# Importing target data from internet in runtime
label_url="https://archive.ics.uci.edu/ml/machine-learning-databases/secom/secom_labels.data"

# %%
# Assigning target data to a pandas dataframe
secom_labels = pd.read_csv(label_url, sep = " ",header=None)

# %%
# Renaming the columns 
secom_labels.columns = ["Classification","Timestamp"]

# %%
# Changing datatype for consitency
secom_labels['Timestamp'] = pd.to_datetime(secom_labels['Timestamp'],errors='raise')

# %%
# Merging the data
data= pd.concat([secom_labels,secom_data],axis=1)

# %%
# Dropping the timestamp column as it provides no insights
data.drop(columns="Timestamp", errors='raise',inplace=True)

# %%
target = data[['Classification']]
data.drop(['Classification'], axis=1,inplace=True)

# %% [markdown]
# #### Spliting the data into training set and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data,target, test_size=0.20, random_state=42, stratify=target)
# We use the startify parameter as the data is imbalanced on the basis of pass and fail and this will ensure the same 
#is retained when we split - Random state will help us create a reproducible data - Test size is the split ration

# %%
X_test_original = X_test

# %% [markdown]
# #### Re-labeling the Target values

# %%
# # Relabeling target variables 1 is pass and 0 is fail
# y_train = y_train.replace(to_replace=[-1, 1], value=[1, 0])
# y_test = y_test.replace(to_replace=[-1, 1], value=[1, 0])

# %%
# # Scaling the data
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
# X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# # Decision : Removing columns with more that 50% missing values

# %%
X_train.shape
# Out:
# (1253, 590)

# %%
X_train_missing = X_train
missing_remove(X_train_missing, 0.5)
X_train_missing.shape
# Out:
# # Features deleted with more than 0.5 % missing values 32
# (1253, 558)

# %% [markdown]
# ## Removing Unique cols

# %%
# X_train_unique = X_train_missing
# unique_remove(X_train_unique)
# X_train_unique.shape

# %%
# From test set deleting columns that are removed in training set
X_test_missing = X_test[np.array(X_train_missing.columns)]
X_test_missing.shape
# Out:
# (314, 558)

# %% [markdown]
# # Decision : Replacing outliers with 3s boundary

# %% [markdown]
# ##### Other option of removing outliers and replacing them has been explored in file "Base file - removing outliers and replacing with knn.ipynb"

# %%
def replace_outlier(val, mean, std):
    if val > mean + 3*std:
        return mean + 3*std 
    elif val < mean - 3*std:
        return mean - 3*std
    return val

# %%
# replace with 3s in X_train
for col in X_train_missing.columns:
    mean = X_train_missing[col].mean()
    std_dev = X_train_missing[col].std(axis=0)
    X_train_missing[col] = X_train_missing[col].map(lambda x: replace_outlier(x, mean, std_dev))

# %%
# replace with 3s in X_test
for col in X_test_missing.columns:
    mean = X_test_missing[col].mean()
    std_dev = X_test_missing[col].std(axis=0)
    X_test_missing[col] = X_test_missing[col].map(lambda x: replace_outlier(x, mean, std_dev))

# %% [markdown]
# # KNN Imputation

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer()
knn.fit(X_train_missing)
X_train_knn=pd.DataFrame(knn.transform(X_train_missing), columns=X_train_missing.columns)
X_train_knn.isna().sum().sum()
# Out:
# 0

# %%
from sklearn.impute import KNNImputer
knn = KNNImputer()
knn.fit(X_test_missing)
X_test_knn=pd.DataFrame(knn.transform(X_test_missing), columns=X_test_missing.columns)
X_test_knn.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Boruta - 15 features

# %%
pip install boruta
# Out:
# Requirement already satisfied: boruta in c:\users\public\anaconda3\lib\site-packages (0.3)
# Requirement already satisfied: numpy>=1.10.4 in c:\users\public\anaconda3\lib\site-packages (from boruta) (1.20.3)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\public\anaconda3\lib\site-packages (from boruta) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.17.1 in c:\users\public\anaconda3\lib\site-packages (from boruta) (1.1.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\public\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\public\anaconda3\lib\site-packages (from scikit-learn>=0.17.1->boruta) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Boruta function

def BorutaFeatureSelection (X, y) :
    feature_names = np.array(X.columns)

    model = model = RandomForestClassifier(n_estimators=200, n_jobs=-1, max_depth=8,class_weight='balanced_subsample')
    model.fit(X, y)
    
    feature_selector = BorutaPy(model, random_state=42, verbose=2,max_iter=250,n_estimators=200)

    feature_selector.fit(X.to_numpy(),y)

    feature_selector.support_

    feature_selector.ranking_

    feature_ranks = list(zip(feature_names, 
                             feature_selector.ranking_, 
                             feature_selector.support_))

    for feat in feature_ranks:
        print('Feature: {:<30} Rank: {},  Keep: {}'.format(feat[0], feat[1], feat[2]))
        
    final_features = list()
    indexes = np.where(feature_selector.ranking_ <= 1)
    for x in np.nditer(indexes):
        final_features.append(feature_names[x])
    print(final_features)
    
    return pd.DataFrame(X.filter(final_features)) , final_features

# %%
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy
X_train_boruta , final_features = BorutaFeatureSelection(X_train_knn,y_train.values.ravel())
# Out:
# Iteration: 	1 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	2 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	3 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	4 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	5 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	6 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	7 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	8 / 250
# Confirmed: 	0
# Tentative: 	25
# Rejected: 	533
# Iteration: 	9 / 250
# Confirmed: 	3
# Tentative: 	22
# Rejected: 	533
# Iteration: 	10 / 250
# Confirmed: 	3
# Tentative: 	22
# Rejected: 	533
# Iteration: 	11 / 250
# Confirmed: 	3
# Tentative: 	22
# Rejected: 	533
# Iteration: 	12 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	13 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	14 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	15 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	16 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	17 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	18 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	19 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	20 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	21 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	22 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	23 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	24 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	25 / 250
# Confirmed: 	3
# Tentative: 	16
# Rejected: 	539
# Iteration: 	26 / 250
# Confirmed: 	5
# Tentative: 	14
# Rejected: 	539
# Iteration: 	27 / 250
# Confirmed: 	5
# Tentative: 	14
# Rejected: 	539
# Iteration: 	28 / 250
# Confirmed: 	5
# Tentative: 	14
# Rejected: 	539
# Iteration: 	29 / 250
# Confirmed: 	6
# Tentative: 	13
# Rejected: 	539
# Iteration: 	30 / 250
# Confirmed: 	6
# Tentative: 	13
# Rejected: 	539
# Iteration: 	31 / 250
# Confirmed: 	6
# Tentative: 	13
# Rejected: 	539
# Iteration: 	32 / 250
# Confirmed: 	6
# Tentative: 	12
# Rejected: 	540
# Iteration: 	33 / 250
# Confirmed: 	6
# Tentative: 	12
# Rejected: 	540
# Iteration: 	34 / 250
# Confirmed: 	9
# Tentative: 	9
# Rejected: 	540
# Iteration: 	35 / 250
# Confirmed: 	9
# Tentative: 	9
# Rejected: 	540
# Iteration: 	36 / 250
# Confirmed: 	9
# Tentative: 	9
# Rejected: 	540
# Iteration: 	37 / 250
# Confirmed: 	9
# Tentative: 	9
# Rejected: 	540
# Iteration: 	38 / 250
# Confirmed: 	9
# Tentative: 	9
# Rejected: 	540
# Iteration: 	39 / 250
# Confirmed: 	9
# Tentative: 	9
# Rejected: 	540
# Iteration: 	40 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	41 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	42 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	43 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	44 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	45 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	46 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	47 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	48 / 250
# Confirmed: 	10
# Tentative: 	8
# Rejected: 	540
# Iteration: 	49 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	50 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	51 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	52 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	53 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	54 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	55 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	56 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	57 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	58 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	59 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	60 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	61 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	62 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	63 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	64 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	65 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	66 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	67 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	68 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	69 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	70 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	71 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	72 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	73 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	74 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	75 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	76 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	77 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	78 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	79 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	80 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	81 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	82 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	83 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	84 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	85 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	86 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	87 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	88 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	89 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	90 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	91 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	92 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	93 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	94 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	95 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	96 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	97 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	98 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	99 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	100 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	101 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	102 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	103 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	104 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	105 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	106 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	107 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	108 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	109 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	110 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	111 / 250
# Confirmed: 	11
# Tentative: 	7
# Rejected: 	540
# Iteration: 	112 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	113 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	114 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	115 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	116 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	117 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	118 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	119 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	120 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	121 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	122 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	123 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	124 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	125 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	126 / 250
# Confirmed: 	12
# Tentative: 	6
# Rejected: 	540
# Iteration: 	127 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	128 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	129 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	130 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	131 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	132 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	133 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	134 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	135 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	136 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	137 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	138 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	139 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	140 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	141 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	142 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	143 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	144 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	145 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	146 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	147 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	148 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	149 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	150 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	151 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	152 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	153 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	154 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	155 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	156 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	157 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	158 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	159 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	160 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	161 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	162 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	163 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	164 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	165 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	166 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	167 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	168 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	169 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	170 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	171 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	172 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	173 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	174 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	175 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	176 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	177 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	178 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	179 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	180 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	181 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	182 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	183 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	184 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	185 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	186 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	187 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	188 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	189 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	190 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	191 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	192 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	193 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	194 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	195 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	196 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	197 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	198 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	199 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	200 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	201 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	202 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	203 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	204 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	205 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	206 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	207 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	208 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	209 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	210 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	211 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	212 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	213 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	214 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	215 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	216 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	217 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	218 / 250
# Confirmed: 	13
# Tentative: 	5
# Rejected: 	540
# Iteration: 	219 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	220 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	221 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	222 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	223 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	224 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	225 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	226 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	227 / 250
# Confirmed: 	14
# Tentative: 	4
# Rejected: 	540
# Iteration: 	228 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	229 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	230 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	231 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	232 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	233 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	234 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	235 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	236 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	237 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	238 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	239 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	240 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	241 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	242 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	243 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	244 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	245 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	246 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	247 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	248 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Iteration: 	249 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
#
#
# BorutaPy finished running.
#
# Iteration: 	250 / 250
# Confirmed: 	15
# Tentative: 	3
# Rejected: 	540
# Feature: Feature_1                      Rank: 43,  Keep: False
# Feature: Feature_2                      Rank: 338,  Keep: False
# Feature: Feature_3                      Rank: 321,  Keep: False
# Feature: Feature_4                      Rank: 392,  Keep: False
# Feature: Feature_5                      Rank: 224,  Keep: False
# Feature: Feature_6                      Rank: 481,  Keep: False
# Feature: Feature_7                      Rank: 315,  Keep: False
# Feature: Feature_8                      Rank: 185,  Keep: False
# Feature: Feature_9                      Rank: 141,  Keep: False
# Feature: Feature_10                     Rank: 147,  Keep: False
# Feature: Feature_11                     Rank: 126,  Keep: False
# Feature: Feature_12                     Rank: 360,  Keep: False
# Feature: Feature_13                     Rank: 230,  Keep: False
# Feature: Feature_14                     Rank: 481,  Keep: False
# Feature: Feature_15                     Rank: 27,  Keep: False
# Feature: Feature_16                     Rank: 35,  Keep: False
# Feature: Feature_17                     Rank: 69,  Keep: False
# Feature: Feature_18                     Rank: 114,  Keep: False
# Feature: Feature_19                     Rank: 340,  Keep: False
# Feature: Feature_20                     Rank: 63,  Keep: False
# Feature: Feature_21                     Rank: 352,  Keep: False
# Feature: Feature_22                     Rank: 1,  Keep: True
# Feature: Feature_23                     Rank: 73,  Keep: False
# Feature: Feature_24                     Rank: 283,  Keep: False
# Feature: Feature_25                     Rank: 233,  Keep: False
# Feature: Feature_26                     Rank: 222,  Keep: False
# Feature: Feature_27                     Rank: 235,  Keep: False
# Feature: Feature_28                     Rank: 208,  Keep: False
# Feature: Feature_29                     Rank: 5,  Keep: False
# Feature: Feature_30                     Rank: 398,  Keep: False
# Feature: Feature_31                     Rank: 244,  Keep: False
# Feature: Feature_32                     Rank: 1,  Keep: True
# Feature: Feature_33                     Rank: 117,  Keep: False
# Feature: Feature_34                     Rank: 1,  Keep: True
# Feature: Feature_35                     Rank: 315,  Keep: False
# Feature: Feature_36                     Rank: 132,  Keep: False
# Feature: Feature_37                     Rank: 290,  Keep: False
# Feature: Feature_38                     Rank: 44,  Keep: False
# Feature: Feature_39                     Rank: 55,  Keep: False
# Feature: Feature_40                     Rank: 70,  Keep: False
# Feature: Feature_41                     Rank: 86,  Keep: False
# Feature: Feature_42                     Rank: 178,  Keep: False
# Feature: Feature_43                     Rank: 481,  Keep: False
# Feature: Feature_44                     Rank: 152,  Keep: False
# Feature: Feature_45                     Rank: 193,  Keep: False
# Feature: Feature_46                     Rank: 82,  Keep: False
# Feature: Feature_47                     Rank: 406,  Keep: False
# Feature: Feature_48                     Rank: 95,  Keep: False
# Feature: Feature_49                     Rank: 136,  Keep: False
# Feature: Feature_50                     Rank: 481,  Keep: False
# Feature: Feature_51                     Rank: 187,  Keep: False
# Feature: Feature_52                     Rank: 248,  Keep: False
# Feature: Feature_53                     Rank: 481,  Keep: False
# Feature: Feature_54                     Rank: 180,  Keep: False
# Feature: Feature_55                     Rank: 261,  Keep: False
# Feature: Feature_56                     Rank: 53,  Keep: False
# Feature: Feature_57                     Rank: 41,  Keep: False
# Feature: Feature_58                     Rank: 312,  Keep: False
# Feature: Feature_59                     Rank: 36,  Keep: False
# Feature: Feature_571                    Rank: 224,  Keep: False
# Feature: Feature_572                    Rank: 214,  Keep: False
# Feature: Feature_573                    Rank: 318,  Keep: False
# Feature: Feature_574                    Rank: 57,  Keep: False
# Feature: Feature_575                    Rank: 189,  Keep: False
# Feature: Feature_576                    Rank: 146,  Keep: False
# Feature: Feature_577                    Rank: 189,  Keep: False
# Feature: Feature_578                    Rank: 20,  Keep: False
# Feature: Feature_583                    Rank: 227,  Keep: False
# Feature: Feature_584                    Rank: 306,  Keep: False
# Feature: Feature_585                    Rank: 376,  Keep: False
# Feature: Feature_586                    Rank: 346,  Keep: False
# Feature: Feature_587                    Rank: 237,  Keep: False
# Feature: Feature_588                    Rank: 17,  Keep: False
# Feature: Feature_589                    Rank: 162,  Keep: False
# Feature: Feature_590                    Rank: 287,  Keep: False
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RASHMI~1\AppData\Local\Temp/ipykernel_20196/3211052677.py in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 from boruta import BorutaPy
# ----> 3 X_train_boruta , final_features = BorutaFeatureSelection(X_train_knn,y_train.values.ravel())
#
# C:\Users\RASHMI~1\AppData\Local\Temp/ipykernel_20196/217107468.py in BorutaFeatureSelection(X, y)
#      26     for x in np.nditer(indexes):
#      27         final_features.append(feature_names[x])
# ---> 28     print(final_features,tentative)
#      29
#      30     return pd.DataFrame(X.filter(final_features)) , final_features
#
# NameError: name 'tentative' is not defined

# %%
# From test set deleting columns that are removed in training set
X_test_boruta = X_test_knn[np.array(X_train_boruta.columns)]
X_test_boruta.shape

# %% [markdown]
# ## Balancing using SMOTE

# %%
import numpy as np
from imblearn.over_sampling import SMOTE, ADASYN, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from sklearn.decomposition import PCA

# %%
from imblearn.combine import SMOTETomek 
# Sampling technique

def Sampling(X_train, y_train, sampler):

    #SMOTE
    if sampler == 'SMOTE':
        sampler = SMOTE(random_state=100)    
    

    #SMOTTEENN
    if sampler == 'SMOTEENN' :
        sampler = SMOTEENN(random_state=100)
        
    # SMOTETOMEK
    
    if sampler == 'SMOTETOMEK' :
        sampler = SMOTETomek(random_state=100)

    #ADASYN
    if sampler == 'ADASYN':
        sampler = ADASYN(random_state=100)
        
    #ROSE
    if sampler == 'ROSE':
        sampler = RandomOverSampler(random_state=100, shrinkage=1)
        

    X_resampled, y_resampled = sampler.fit_resample(X_train, y_train)
    counter = Counter(y_resampled)
    print(counter)
    return X_resampled, y_resampled

# %% [markdown]
# ## Rose

# %%
# Imbalance treatment
from collections import Counter
from sklearn.metrics import f1_score, matthews_corrcoef
X_rose, y_rose = Sampling(X_train_boruta, y_train,'ROSE')

# %%
evaluate2(RandomForestClassifier(n_jobs=-1, class_weight='balanced_subsample', max_depth=6, random_state=100),X_rose,X_test_boruta,y_rose,y_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

# %%
X_rose

# %%
# Random forest
params = {'criterion' : ["gini","entropy","log_loss"],
          'max_depth':[1,2, 3,4, 5,6,7,8],
         'max_features':["sqrt","log2", None]}
          

grid_searcher = GridSearchCV(RandomForestClassifier(), params,scoring='roc_auc', cv = 5, verbose=1)
grid_searcher.fit(X_rose, y_rose)
#plot_result_smoted_fe_tuned(grid_searcher, "dtc")

# %%
grid_searcher.best_params_

# %%
grid_searcher.best_estimator_

# %%
evaluate2(grid_searcher.best_estimator_,X_rose,X_test_boruta,y_rose,y_test)

# %%
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split # for separating train and test data, scaling, model building, ...

# Evaluation using Startified K Fold cross validation
cv = StratifiedKFold(n_splits=5)
scores = cross_val_score(grid_searcher.best_estimator_, X_rose, y_rose, cv=cv, scoring = 'roc_auc')
print(scores.mean())
# fit
grid_searcher.best_estimator_.fit(X_rose, y_rose)    
# predict
y_pred_test = grid_searcher.best_estimator_.predict(X_test_boruta)
# View accuracy score
accuracyFinal = accuracy_score(y_test, y_pred_test)
print('Test Accuracy : ', accuracyFinal)

# %%
from boruta import BorutaPy
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=500)

trans = BorutaPy(clf, verbose=2,max_iter=250)
sel = trans.fit_transform(X_train_knn.values, y_train.values.ravel())
# Out:
# Iteration: 	1 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	2 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	3 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	4 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	5 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	6 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	7 / 250
# Confirmed: 	0
# Tentative: 	558
# Rejected: 	0
# Iteration: 	8 / 250
# Confirmed: 	0
# Tentative: 	14
# Rejected: 	544
# Iteration: 	9 / 250
# Confirmed: 	3
# Tentative: 	11
# Rejected: 	544
# Iteration: 	10 / 250
# Confirmed: 	3
# Tentative: 	11
# Rejected: 	544
# Iteration: 	11 / 250
# Confirmed: 	3
# Tentative: 	11
# Rejected: 	544
# Iteration: 	12 / 250
# Confirmed: 	3
# Tentative: 	11
# Rejected: 	544
# Iteration: 	13 / 250
# Confirmed: 	3
# Tentative: 	11
# Rejected: 	544
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\RASHMI~1\AppData\Local\Temp/ipykernel_20196/4078268452.py in <module>
#       4
#       5 trans = BorutaPy(clf, verbose=2,max_iter=250)
# ----> 6 sel = trans.fit_transform(X_train_knn.values, y_train.values.ravel())
#
# C:\Users\public\anaconda3\lib\site-packages\boruta\boruta_py.py in fit_transform(self, X, y, weak)
#     244         """
#     245
# --> 246         self._fit(X, y)
#     247         return self._transform(X, weak)
#     248
#
# C:\Users\public\anaconda3\lib\site-packages\boruta\boruta_py.py in _fit(self, X, y)
#     283
#     284             # add shadow attributes, shuffle them and train estimator, get imps
# --> 285             cur_imp = self._add_shadows_get_imps(X, y, dec_reg)
#     286
#     287             # get the threshold of shadow importances we will use for rejection
#
# C:\Users\public\anaconda3\lib\site-packages\boruta\boruta_py.py in _add_shadows_get_imps(self, X, y, dec_reg)
#     410         x_sha = np.apply_along_axis(self._get_shuffle, 0, x_sha)
#     411         # get importance of the merged matrix
# --> 412         imp = self._get_imp(np.hstack((x_cur, x_sha)), y)
#     413         # separate importances of real and shadow features
#     414         imp_sha = imp[x_cur_w:]
#
# C:\Users\public\anaconda3\lib\site-packages\boruta\boruta_py.py in _get_imp(self, X, y)
#     382     def _get_imp(self, X, y):
#     383         try:
# --> 384             self.estimator.fit(X, y)
#     385         except Exception as e:
#     386             raise ValueError('Please check your X and y variable. The provided'
#
# C:\Users\public\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     474             # parallel_backend contexts set at a higher level,
#     475             # since correctness does not rely on using threads.
# --> 476             trees = Parallel(
#     477                 n_jobs=self.n_jobs,
#     478                 verbose=self.verbose,
#
# C:\Users\public\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# C:\Users\public\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# C:\Users\public\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# C:\Users\public\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# C:\Users\public\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# C:\Users\public\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# C:\Users\public\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# C:\Users\public\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     115     def __call__(self, *args, **kwargs):
#     116         with config_context(**self.config):
# --> 117             return self.function(*args, **kwargs)
#     118
#     119
#
# C:\Users\public\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     187             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     188
# --> 189         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     190     else:
#     191         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# C:\Users\public\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input)
#     967         """
#     968
# --> 969         super().fit(
#     970             X,
#     971             y,
#
# C:\Users\public\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input)
#     456             )
#     457
# --> 458         builder.build(self.tree_, X, y, sample_weight)
#     459
#     460         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
trans
